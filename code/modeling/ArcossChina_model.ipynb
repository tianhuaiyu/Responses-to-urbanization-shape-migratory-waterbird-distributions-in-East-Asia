# %% [markdown]
# ## figure S2

# %%
import os 
import numpy as np
import pandas as pd
import xgboost as xgb
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt  
import matplotlib.colors as col

from pdpbox import pdp
from matplotlib import cm
from pdpbox import info_plots
from xgboost.sklearn import XGBClassifier
from sklearn.metrics import roc_auc_score
from matplotlib.pyplot import MultipleLocator

plt.rc('font',family='Arial')
plt.rcParams ['svg.fonttype'] ='none'
plt.rcParams ['svg.fonttype'] ='none'
pd.options.mode.chained_assignment = None
# %matplotlib inline

# %% [markdown]
# ### load data

# %%
#train 
train = pd.read_csv(r'../../data/total/train.csv',index_col=0)
train['month'] = train['date'].apply(lambda x:pd.Timestamp(x).month)
train = train.drop(columns=['date','lon','lat','Open Water','Urban-Built-up'])
X_train=train.iloc[:,1:]
y_train=train.iloc[:,0]
#test 
test = pd.read_csv(r'../../data/total/test.csv',index_col=0)
test['month'] = test['date'].apply(lambda x:pd.Timestamp(x).month)
test = test.drop(columns=['date','lon','lat','Open Water','Urban-Built-up'])
X_test=test.iloc[:,1:]
y_test=test.iloc[:,0]

# %% [markdown]
# ### train model

# %%
xgb_model = XGBClassifier(
                  n_jobs=4,
                  max_depth=18,
                  learning_rate=0.12,
                  n_estimators=1200,
                  verbosity=1,
                  objective='binary:logistic',
                  booster='gbtree',
                  gamma=0.1,
                  min_child_weight=4,
                  subsample=0.6,
                  colsample_bytree=0.8,
                  reg_alpha=1,
                  reg_lambda=2,
                  base_score=0.5,
                  eval_metric='auc',
          )
xgb_model.fit(X_train, y_train,eval_set=[(X_test, y_test)],early_stopping_rounds=75,verbose=True)
# Out:
# [0]	validation_0-auc:0.64338
# Will train until validation_0-auc hasn't improved in 75 rounds.
# [1]	validation_0-auc:0.65636
# [2]	validation_0-auc:0.65996
# [3]	validation_0-auc:0.66433
# [4]	validation_0-auc:0.66432
# [5]	validation_0-auc:0.67264
# [6]	validation_0-auc:0.67614
# [7]	validation_0-auc:0.67319
# [8]	validation_0-auc:0.68021
# [9]	validation_0-auc:0.68014
# [10]	validation_0-auc:0.67665
# [11]	validation_0-auc:0.67953
# [12]	validation_0-auc:0.67888
# [13]	validation_0-auc:0.68330
# [14]	validation_0-auc:0.68402
# [15]	validation_0-auc:0.68903
# [16]	validation_0-auc:0.69057
# [17]	validation_0-auc:0.69355
# [18]	validation_0-auc:0.69460
# [19]	validation_0-auc:0.69523
# [20]	validation_0-auc:0.69553
# [21]	validation_0-auc:0.69807
# [22]	validation_0-auc:0.69807
# [23]	validation_0-auc:0.69986
# [24]	validation_0-auc:0.70238
# [25]	validation_0-auc:0.70551
# [26]	validation_0-auc:0.70612
# [27]	validation_0-auc:0.70685
# [28]	validation_0-auc:0.71166
# [29]	validation_0-auc:0.71203
# [30]	validation_0-auc:0.71582
# [31]	validation_0-auc:0.71732
# [32]	validation_0-auc:0.71702
# [33]	validation_0-auc:0.71879
# [34]	validation_0-auc:0.71949
# [35]	validation_0-auc:0.72053
# [36]	validation_0-auc:0.71974
# [37]	validation_0-auc:0.71974
# [38]	validation_0-auc:0.71831
# [39]	validation_0-auc:0.72037
# [40]	validation_0-auc:0.72231
# [41]	validation_0-auc:0.72298
# [42]	validation_0-auc:0.72230
# [43]	validation_0-auc:0.72292
# [44]	validation_0-auc:0.72467
# [45]	validation_0-auc:0.72503
# [46]	validation_0-auc:0.72437
# [47]	validation_0-auc:0.72425
# [48]	validation_0-auc:0.72453
# [49]	validation_0-auc:0.72485
# [50]	validation_0-auc:0.72425
# [51]	validation_0-auc:0.72455
# [52]	validation_0-auc:0.72391
# [53]	validation_0-auc:0.72487
# [54]	validation_0-auc:0.72616
# [55]	validation_0-auc:0.72628
# [56]	validation_0-auc:0.72730
# [57]	validation_0-auc:0.72727
# [58]	validation_0-auc:0.72807
# [59]	validation_0-auc:0.72714
# [60]	validation_0-auc:0.72800
# [61]	validation_0-auc:0.72841
# [62]	validation_0-auc:0.72805
# [63]	validation_0-auc:0.72877
# [64]	validation_0-auc:0.72904
# [65]	validation_0-auc:0.72893
# [66]	validation_0-auc:0.72821
# [67]	validation_0-auc:0.72836
# [68]	validation_0-auc:0.73070
# [69]	validation_0-auc:0.73100
# [70]	validation_0-auc:0.73095
# [71]	validation_0-auc:0.73034
# [72]	validation_0-auc:0.72984
# [73]	validation_0-auc:0.73025
# [74]	validation_0-auc:0.73052
# [75]	validation_0-auc:0.73154
# [76]	validation_0-auc:0.73098
# [77]	validation_0-auc:0.73165
# [78]	validation_0-auc:0.73145
# [79]	validation_0-auc:0.73149
# [80]	validation_0-auc:0.73233
# [81]	validation_0-auc:0.73444
# [82]	validation_0-auc:0.73562
# [83]	validation_0-auc:0.73604
# [84]	validation_0-auc:0.73780
# [85]	validation_0-auc:0.73723
# [86]	validation_0-auc:0.73744
# [87]	validation_0-auc:0.73785
# [88]	validation_0-auc:0.73710
# [89]	validation_0-auc:0.73676
# [90]	validation_0-auc:0.73597
# [91]	validation_0-auc:0.73628
# [92]	validation_0-auc:0.73585
# [93]	validation_0-auc:0.73567
# [94]	validation_0-auc:0.73590
# [95]	validation_0-auc:0.73597
# [96]	validation_0-auc:0.73681
# [97]	validation_0-auc:0.73689
# [98]	validation_0-auc:0.73651
# [99]	validation_0-auc:0.73606
# [100]	validation_0-auc:0.73730
# [101]	validation_0-auc:0.73765
# [102]	validation_0-auc:0.73896
# [103]	validation_0-auc:0.73908
# [104]	validation_0-auc:0.73942
# [105]	validation_0-auc:0.73935
# [106]	validation_0-auc:0.73939
# [107]	validation_0-auc:0.73987
# [108]	validation_0-auc:0.73994
# [109]	validation_0-auc:0.73916
# [110]	validation_0-auc:0.73794
# [111]	validation_0-auc:0.73798
# [112]	validation_0-auc:0.73850
# [113]	validation_0-auc:0.73862
# [114]	validation_0-auc:0.73828
# [115]	validation_0-auc:0.73946
# [116]	validation_0-auc:0.73971
# [117]	validation_0-auc:0.73982
# [118]	validation_0-auc:0.73942
# [119]	validation_0-auc:0.73933
# [120]	validation_0-auc:0.73910
# [121]	validation_0-auc:0.73883
# [122]	validation_0-auc:0.73873
# [123]	validation_0-auc:0.73871
# [124]	validation_0-auc:0.73928
# [125]	validation_0-auc:0.73898
# [126]	validation_0-auc:0.73978
# [127]	validation_0-auc:0.74014
# [128]	validation_0-auc:0.74135
# [129]	validation_0-auc:0.74050
# [130]	validation_0-auc:0.74114
# [131]	validation_0-auc:0.74112
# [132]	validation_0-auc:0.74161
# [133]	validation_0-auc:0.74118
# [134]	validation_0-auc:0.74275
# [135]	validation_0-auc:0.74277
# [136]	validation_0-auc:0.74296
# [137]	validation_0-auc:0.74252
# [138]	validation_0-auc:0.74202
# [139]	validation_0-auc:0.74236
# [140]	validation_0-auc:0.74250
# [141]	validation_0-auc:0.74338
# [142]	validation_0-auc:0.74434
# [143]	validation_0-auc:0.74493
# [144]	validation_0-auc:0.74482
# [145]	validation_0-auc:0.74482
# [146]	validation_0-auc:0.74477
# [147]	validation_0-auc:0.74472
# [148]	validation_0-auc:0.74454
# [149]	validation_0-auc:0.74481
# [150]	validation_0-auc:0.74529
# [151]	validation_0-auc:0.74493
# [152]	validation_0-auc:0.74447
# [153]	validation_0-auc:0.74355
# [154]	validation_0-auc:0.74305
# [155]	validation_0-auc:0.74348
# [156]	validation_0-auc:0.74381
# [157]	validation_0-auc:0.74363
# [158]	validation_0-auc:0.74339
# [159]	validation_0-auc:0.74348
# [160]	validation_0-auc:0.74305
# [161]	validation_0-auc:0.74288
# [162]	validation_0-auc:0.74368
# [163]	validation_0-auc:0.74350
# [164]	validation_0-auc:0.74391
# [165]	validation_0-auc:0.74404
# [166]	validation_0-auc:0.74384
# [167]	validation_0-auc:0.74389
# [168]	validation_0-auc:0.74418
# [169]	validation_0-auc:0.74425
# [170]	validation_0-auc:0.74413
# [171]	validation_0-auc:0.74382
# [172]	validation_0-auc:0.74354
# [173]	validation_0-auc:0.74347
# [174]	validation_0-auc:0.74377
# [175]	validation_0-auc:0.74443
# [176]	validation_0-auc:0.74475
# [177]	validation_0-auc:0.74418
# [178]	validation_0-auc:0.74386
# [179]	validation_0-auc:0.74397
# [180]	validation_0-auc:0.74441
# [181]	validation_0-auc:0.74393
# [182]	validation_0-auc:0.74422
# [183]	validation_0-auc:0.74441
# [184]	validation_0-auc:0.74423
# [185]	validation_0-auc:0.74386
# [186]	validation_0-auc:0.74398
# [187]	validation_0-auc:0.74391
# [188]	validation_0-auc:0.74361
# [189]	validation_0-auc:0.74375
# [190]	validation_0-auc:0.74363
# [191]	validation_0-auc:0.74393
# [192]	validation_0-auc:0.74414
# [193]	validation_0-auc:0.74389
# [194]	validation_0-auc:0.74347
# [195]	validation_0-auc:0.74368
# [196]	validation_0-auc:0.74323
# [197]	validation_0-auc:0.74389
# [198]	validation_0-auc:0.74291
# [199]	validation_0-auc:0.74325
# [200]	validation_0-auc:0.74402
# [201]	validation_0-auc:0.74382
# [202]	validation_0-auc:0.74398
# [203]	validation_0-auc:0.74382
# [204]	validation_0-auc:0.74352
# [205]	validation_0-auc:0.74375
# [206]	validation_0-auc:0.74352
# [207]	validation_0-auc:0.74400
# [208]	validation_0-auc:0.74355
# [209]	validation_0-auc:0.74361
# [210]	validation_0-auc:0.74300
# [211]	validation_0-auc:0.74279
# [212]	validation_0-auc:0.74275
# [213]	validation_0-auc:0.74252
# [214]	validation_0-auc:0.74330
# [215]	validation_0-auc:0.74332
# [216]	validation_0-auc:0.74348
# [217]	validation_0-auc:0.74354
# [218]	validation_0-auc:0.74320
# [219]	validation_0-auc:0.74307
# [220]	validation_0-auc:0.74302
# [221]	validation_0-auc:0.74359
# [222]	validation_0-auc:0.74359
# [223]	validation_0-auc:0.74345
# [224]	validation_0-auc:0.74313
# [225]	validation_0-auc:0.74302
# Stopping. Best iteration:
# [150]	validation_0-auc:0.74529
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.8, eval_metric='auc',
#               gamma=0.1, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.12, max_delta_step=0,
#               max_depth=18, min_child_weight=4, missing=nan,
#               monotone_constraints='()', n_estimators=1200, n_jobs=4,
#               num_parallel_tree=1, random_state=0, reg_alpha=1, reg_lambda=2,
#               scale_pos_weight=1, subsample=0.6, tree_method='exact',
#               validate_parameters=1, verbosity=1)

# %% [markdown]
# ### generate partial dependence plot by pdpbox
# #### Calculate 2d partial dependence plot___pop_density.vs.light

# %%
## 人口密度，还是尽量选择了反映全部的人口密度范围
data_features = list(X_train.columns)

pdp_Pop_dL = pdp.pdp_interact(model=xgb_model,
                                dataset=train,
                                model_features=data_features,
                                features=['Pop', 'distance_light'],
                                num_grid_points=[10, 11],
                                grid_types = ['percentile','percentile'],
                                percentile_ranges=[(0,95),(0,100)],
                                n_jobs=1)

pdp_Pop_dL = pdp.pdp_interact(model=xgb_model,
                                dataset=train,
                                model_features=data_features,
                                features=['Pop', 'distance_light'],
                                cust_grid_points=[pdp_Pop_dL.feature_grids[0].astype(int),pdp_Pop_dL.feature_grids[1].astype(int)],
                                n_jobs=1)
pdp_v = pdp_Pop_dL.pdp.preds.values
pdp_v.resize(8,11)
pd_pdp = pd.DataFrame(pdp_v).T
pd_pdp.columns = np.array(pdp_Pop_dL.feature_grids[0]).astype(int)#.astype(int)
pd_pdp['Distance to light'] = pdp_Pop_dL.feature_grids[1].astype(int)
pd_pdp = pd_pdp.set_index('Distance to light')
pd_pdp.to_csv(r'../../result/figure_data/2d_pdp/figure_S2.csv')

# %%
file = r'../../result/figure_data/2d_pdp/figure_S2.csv'
df = pd.read_csv(file).sort_values(by='Distance to light',ascending=False)
df['Distance to light'] = df.apply(lambda x:round(x['Distance to light'],1),axis=1)
df = df.sort_values('Distance to light',ascending=False)
df = df.set_index('Distance to light')
grid_kws = {"width_ratios": (0.9, 0.06)}  
fig, (ax, cbar_ax)  = plt.subplots(1, 2,gridspec_kw=grid_kws,figsize=(10,11)) 
sns.heatmap(data=df,cmap='RdYlBu_r',vmin=0.44,vmax=0.56,center=0.5,linewidths=0,robust=False,square=False,ax=ax,cbar_ax=cbar_ax,cbar_kws={"orientation": "vertical"})
ax.set_xticklabels(df.columns.to_list(),rotation=0,fontdict={'size':22})
ax.set_yticklabels(np.array(df.index).astype(int),rotation=0,fontdict={'size':26})
ax.set_ylabel("Distance to light (Km)",fontdict={'size':26},labelpad=5)
ax.set_xlabel('People/$\mathregular{km^2}$',fontdict={'size':26},labelpad=5)
cbar_ax.set_yticklabels((cbar_ax.get_yticklabels()),fontdict={'size':22})
cbar_ax.margins(0.02)
plt.subplots_adjust(left = None,bottom = None,right =None,top = None,wspace = 0.1,hspace = None)
plt.savefig(r'../../result/figure/2d_pdp/figure_S2.pdf',dpi=300,bbox_inches = 'tight')
plt.savefig(r'../../result/figure/2d_pdp/figure_S2.png',dpi=300,bbox_inches = 'tight')
