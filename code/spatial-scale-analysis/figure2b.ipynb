# %% [markdown]
# The code to generate figure2b and S7

# %%
import pandas as pd
import os 
import numpy as np
import matplotlib.pyplot as plt  
from matplotlib import cm
from matplotlib.lines import Line2D
import seaborn as sns
plt.rc('font',family='Arial')
from matplotlib.ticker import MultipleLocator, FormatStrFormatter

# %%
fig,ax = plt.subplots(figsize = (6,1))
#sns.set(style='white', font='sans-serif',font_scale=2)
sns.despine(top=True, right=True, left=True, bottom=True,ax=ax)
custom_lines = [
                Line2D([0], [0], color="#F03A39", lw=3,alpha=1),##F02A2A,#F05339,#F03A39
                Line2D([0], [0], color="#000000", lw=3,alpha=1),##5866AF,5833AF,606060
                Line2D([0], [0], color='#606060', lw=3,alpha=0.6),
                ]
plt.axis('off')
ax.legend(custom_lines, ['Original','Average noises','Random noises'],frameon=False,ncol=3,fontsize=20)#,loc=(0.65,0.85)
plt.savefig(r'F:\data\china gps\noise\noise_added_pdp/legend2.png',dpi=600,bbox_inches = 'tight')

# %% [markdown]
# ### figure2——5km and 100km
#
# #### East
# #### 5km

# %%
f = 'distance_light'
q = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_5km/8/plot/east/pdp_csv/pdp_distance_light.csv')## 这里是先搞一个统一的distance_light
q.columns = ['distance_light','random_0']
for i in range(0,50):
    pdp_path = '/home/wb/Documents/nc_noiseanalysi/noise/noise_5km/%s/plot'%i
    region = 'east'
    pdpfile = pdp_path+'/%s'%region+'/pdp_csv/'+"pdp_%s.csv"%f
    pdpfile = pd.read_csv(pdpfile)
    column_name = 'random_'+str(i)
    q[column_name]= pdpfile['partial_dependence']
q['init_pdp'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['partial_dependence']
q['init_x'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['distance_light']
q['mean_pdp'] = q.iloc[:,1:-2].mean(axis=1)
q.iloc[20,-2]=400

fig,ax = plt.subplots(figsize = (4,8))
sns.set(style='white', font='sans-serif',font_scale=2)

for i in range(0,50):
    sns.lineplot(x='distance_light',y='random_%s'%i,data=q,ax=ax,color="#606060",linewidth=1.2,alpha=0.6)
    #ax.set_ybound(0.45,0.55)
sns.lineplot(x='init_x',y='init_pdp',data=q,ax=ax,color="#F03A39",linewidth=4,alpha=1)
sns.lineplot(x='distance_light',y='mean_pdp',data=q,ax=ax,color="#000000",linewidth=4,alpha=1)

#ax.set_xbound(-20,400)
#ax.set_ybound(0.45,0.60)
ax.set_xticks([0,200,400])
#ax.set_yticks([0.47,0.50,0.54,0.56])
ax.set_xlim(-20,420)
ax.set_ylim(0.47,0.63)
#bins = 
ax.yaxis.set_major_locator(MultipleLocator(0.05))

plt.setp(ax.get_xticklines(),visible=True)
plt.setp(ax.get_yticklines(),visible=True)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

#ax.set_ylabel('Distribution probability',labelpad=10)
ax.set_ylabel(None,labelpad=10)
ax.set_xlabel('Distance to light (km)',labelpad=10)
custom_lines = [
                Line2D([0], [0], color="#F03A39", lw=5,alpha=1),##F02A2A,#F05339,#F03A39
                Line2D([0], [0], color="#000000", lw=5,alpha=1),##5866AF,5833AF,606060
                Line2D([0], [0], color='#606060', lw=5,alpha=0.6),
                ]

#ax.legend(custom_lines, ['Original','Average noises','Random noises'],loc=(0.45,0.01),frameon=False)#,loc=(0.65,0.85)

title_value = pdp_path.split('/')[6].split('_')[1][:-2]
title = '%s km '%title_value
#plt.title(label=title,pad=5,font={'size':35})
#plt.savefig(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_added_pdp//%s/%s.png'%(region,title),dpi=300,bbox_inches = 'tight')#_nospine
plt.savefig(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_added_pdp/figure2/%s/%s.png'%(region,title),dpi=300,bbox_inches = 'tight')#_nospine

# %% [markdown]
# #### 100km

# %%
f = 'distance_light'
q = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_100km/8/plot/east/pdp_csv/pdp_distance_light.csv')## 这里是先搞一个统一的distance_light
q.columns = ['distance_light','random_0']
for i in range(0,50):
    pdp_path = '/home/wb/Documents/nc_noiseanalysi/noise/noise_100km/%s/plot'%i
    region = 'east'
    pdpfile = pdp_path+'/%s'%region+'/pdp_csv/'+"pdp_%s.csv"%f
    pdpfile = pd.read_csv(pdpfile)
    column_name = 'random_'+str(i)
    q[column_name]= pdpfile['partial_dependence']
q['init_pdp'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['partial_dependence']
q['init_x'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['distance_light']
q['mean_pdp'] = q.iloc[:,1:-2].mean(axis=1)
q.iloc[20,-2]=400

fig,ax = plt.subplots(figsize = (4,8))
sns.set(style='white', font='sans-serif',font_scale=2)

for i in range(0,50):
    sns.lineplot(x='distance_light',y='random_%s'%i,data=q,ax=ax,color="#606060",linewidth=1.2,alpha=0.6)
    #ax.set_ybound(0.45,0.55)
sns.lineplot(x='init_x',y='init_pdp',data=q,ax=ax,color="#F03A39",linewidth=4,alpha=1)
sns.lineplot(x='distance_light',y='mean_pdp',data=q,ax=ax,color="#000000",linewidth=4,alpha=1)

ax.set_xticks([0,200,400])
ax.set_xlim(-20,420)
ax.set_ylim(0.47,0.63)
#bins = 
ax.yaxis.set_major_locator(MultipleLocator(0.05))

plt.setp(ax.get_xticklines(),visible=True)
plt.setp(ax.get_yticklines(),visible=True)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

#ax.set_ylabel('Distribution probability',labelpad=10)
ax.set_ylabel(None,labelpad=10)
ax.set_xlabel('Distance to light (km)',labelpad=10)
custom_lines = [
                Line2D([0], [0], color="#F03A39", lw=5,alpha=1),##F02A2A,#F05339,#F03A39
                Line2D([0], [0], color="#000000", lw=5,alpha=1),##5866AF,5833AF,606060
                Line2D([0], [0], color='#606060', lw=5,alpha=0.6),
                ]

#ax.legend(custom_lines, ['Original','Average noises','Random noises'],loc=(0.45,0.01),frameon=False)#,loc=(0.65,0.85)

title_value = pdp_path.split('/')[6].split('_')[1][:-2]
title = '%s km '%title_value
plt.savefig(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_added_pdp/figure2/%s/%s.png'%(region,title),dpi=300,bbox_inches = 'tight')#_nospine

# %% [markdown]
# #### West
# #### 5km

# %%
f = 'distance_light'
q = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_5km/8/plot/west/pdp_csv/pdp_distance_light.csv')## 这里是先搞一个统一的distance_light
q.columns = ['distance_light','random_0']
for i in range(0,50):
    pdp_path = '/home/wb/Documents/nc_noiseanalysi/noise/noise_5km/%s/plot'%i
    region = 'west'
    pdpfile = pdp_path+'/%s'%region+'/pdp_csv/'+"pdp_%s.csv"%f
    pdpfile = pd.read_csv(pdpfile)
    column_name = 'random_'+str(i)
    q[column_name]= pdpfile['partial_dependence']
q['init_pdp'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['partial_dependence']
q['init_x'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['distance_light']
q['mean_pdp'] = q.iloc[:,1:-2].mean(axis=1)
q.iloc[20,-2]=400

fig,ax = plt.subplots(figsize = (4,8))
sns.set(style='white', font='sans-serif',font_scale=2)
#sns.set_context("talk",font_scale=1)
## 注意这里需要更改文件名
#sns.despine(top=True, right=True, left=False, bottom=False,ax=ax)

for i in range(0,50):
    sns.lineplot(x='distance_light',y='random_%s'%i,data=q,ax=ax,color="#606060",linewidth=1.2,alpha=0.6)
    #ax.set_ybound(0.45,0.55)
sns.lineplot(x='init_x',y='init_pdp',data=q,ax=ax,color="#F03A39",linewidth=4,alpha=1)
sns.lineplot(x='distance_light',y='mean_pdp',data=q,ax=ax,color="#000000",linewidth=4,alpha=1)

#ax.set_xbound(-20,400)
#ax.set_ybound(0.45,0.60)
ax.set_xticks([0,200,400])
#ax.set_yticks([0.47,0.50,0.54,0.56])
ax.set_xlim(-20,420)
ax.set_ylim(0.42,0.59)
#bins = 
ax.yaxis.set_major_locator(MultipleLocator(0.05))

plt.setp(ax.get_xticklines(),visible=True)
plt.setp(ax.get_yticklines(),visible=True)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

ax.set_ylabel('Distribution probability',labelpad=10)
ax.set_xlabel('Distance to light (km)',labelpad=10)
custom_lines = [
                Line2D([0], [0], color="#F03A39", lw=5,alpha=1),##F02A2A,#F05339,#F03A39
                Line2D([0], [0], color="#000000", lw=5,alpha=1),##5866AF,5833AF,606060
                Line2D([0], [0], color='#606060', lw=5,alpha=0.6),
                ]

#ax.legend(custom_lines, ['Original','Average noises','Random noises'],loc=(0.45,0.01),frameon=False)#,loc=(0.65,0.85)

title_value = pdp_path.split('/')[6].split('_')[1][:-2]
title = '%s km '%title_value
#plt.title(label=title,pad=5,font={'size':35})
plt.savefig(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_added_pdp/figure2/%s/%s.png'%(region,title),dpi=300,bbox_inches = 'tight')#_nospine

# %%
f = 'distance_light'
q = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_5km/8/plot/west/pdp_csv/pdp_distance_light.csv')## 这里是先搞一个统一的distance_light
q.columns = ['distance_light','random_0']
for i in range(0,50):
    pdp_path = '/home/wb/Documents/nc_noiseanalysi/noise/noise_100km/%s/plot'%i
    region = 'west'
    pdpfile = pdp_path+'/%s'%region+'/pdp_csv/'+"pdp_%s.csv"%f
    pdpfile = pd.read_csv(pdpfile)
    column_name = 'random_'+str(i)
    q[column_name]= pdpfile['partial_dependence']
q['init_pdp'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['partial_dependence']
q['init_x'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['distance_light']
q['mean_pdp'] = q.iloc[:,1:-2].mean(axis=1)
q.iloc[20,-2]=400

fig,ax = plt.subplots(figsize = (4,8))
sns.set(style='white', font='sans-serif',font_scale=2)
#sns.set_context("talk",font_scale=1)
#sns.despine(top=True, right=True, left=False, bottom=False,ax=ax)

for i in range(0,50):
    sns.lineplot(x='distance_light',y='random_%s'%i,data=q,ax=ax,color="#606060",linewidth=1.2,alpha=0.6)
    #ax.set_ybound(0.45,0.55)
sns.lineplot(x='init_x',y='init_pdp',data=q,ax=ax,color="#F03A39",linewidth=4,alpha=1)
sns.lineplot(x='distance_light',y='mean_pdp',data=q,ax=ax,color="#000000",linewidth=4,alpha=1)

#ax.set_xbound(-20,400)
#ax.set_ybound(0.45,0.60)
ax.set_xticks([0,200,400])
#ax.set_yticks([0.47,0.50,0.54,0.56])
ax.set_xlim(-20,420)
ax.set_ylim(0.42,0.59)
#bins = 
ax.yaxis.set_major_locator(MultipleLocator(0.05))

plt.setp(ax.get_xticklines(),visible=True)
plt.setp(ax.get_yticklines(),visible=True)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')

#ax.set_ylabel('Distribution probability',labelpad=10)
ax.set_ylabel(None,labelpad=10)
ax.set_xlabel('Distance to light (km)',labelpad=10)
custom_lines = [
                Line2D([0], [0], color="#F03A39", lw=5,alpha=1),##F02A2A,#F05339,#F03A39
                Line2D([0], [0], color="#000000", lw=5,alpha=1),##5866AF,5833AF,606060
                Line2D([0], [0], color='#606060', lw=5,alpha=0.6),
                ]

#ax.legend(custom_lines, ['Original','Average noises','Random noises'],loc=(0.45,0.01),frameon=False)#,loc=(0.65,0.85)

title_value = pdp_path.split('/')[6].split('_')[1][:-2]
title = '%s km '%title_value
#plt.title(label=title,pad=5,font={'size':35})
plt.savefig(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_added_pdp/figure2/%s/%s.png'%(region,title),dpi=300,bbox_inches = 'tight')#_nospine

# %% [markdown]
# ## figure S7
# ### west

# %%
for noise in [5,10,20,50,100]:
    f = 'distance_light'
    q = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_5km/8/plot/west/pdp_csv/pdp_distance_light.csv')## 这里是先搞一个统一的distance_light
    q.columns = ['distance_light','random_0']
    for i in range(0,50):
        pdp_path = '/home/wb/Documents/nc_noiseanalysi/noise/noise_%skm/%s/plot'%(noise,i)
        region = 'west'
        pdpfile = pdp_path+'/%s'%region+'/pdp_csv/'+"pdp_%s.csv"%f
        pdpfile = pd.read_csv(pdpfile)
        column_name = 'random_'+str(i)
        q[column_name]= pdpfile['partial_dependence']
    q['init_pdp'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['partial_dependence']
    q['init_x'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['distance_light']
    q['mean_pdp'] = q.iloc[:,1:-2].mean(axis=1)
    q.iloc[20,-2]=400

    fig,ax = plt.subplots(figsize = (8,6))
    sns.set(style='white', font='sans-serif',font_scale=2)
    #sns.set_context("talk",font_scale=1)
    #sns.despine(top=True, right=True, left=False, bottom=False,ax=ax)

    for i in range(0,50):
        sns.lineplot(x='distance_light',y='random_%s'%i,data=q,ax=ax,color="#606060",linewidth=1.2,alpha=0.6)
        #ax.set_ybound(0.45,0.55)
    sns.lineplot(x='init_x',y='init_pdp',data=q,ax=ax,color="#F03A39",linewidth=4,alpha=1)
    sns.lineplot(x='distance_light',y='mean_pdp',data=q,ax=ax,color="#000000",linewidth=4,alpha=1)

    #ax.set_xbound(-20,400)
    #ax.set_ybound(0.45,0.60)
    ax.set_xticks([0,100,200,300,400])
    #ax.set_yticks([0.47,0.50,0.54,0.56])
    ax.set_xlim(-20,420)
    ax.set_ylim(0.35,0.60)
    #bins = 
    ax.yaxis.set_major_locator(MultipleLocator(0.05))

    plt.setp(ax.get_xticklines(),visible=True)
    plt.setp(ax.get_yticklines(),visible=True)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_ylabel('Distribution probability',labelpad=10)
    ax.set_xlabel('Distance to light (km)',labelpad=10)
    custom_lines = [
                    Line2D([0], [0], color="#F03A39", lw=5,alpha=1),##F02A2A,#F05339,#F03A39
                    Line2D([0], [0], color="#000000", lw=5,alpha=1),##5866AF,5833AF,606060
                    Line2D([0], [0], color='#606060', lw=5,alpha=0.6),
                    ]

    #ax.legend(custom_lines, ['Original','Average noises','Random noises'],loc=(0.45,0.01),frameon=False)#,loc=(0.65,0.85)
    title_value = pdp_path.split('/')[6].split('_')[1][:-2]
    title = '%s km '%title_value
    plt.title(label=title,pad=5,font={'size':28})
    plt.savefig(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_added_pdp/%s/%s.png'%(region,title),dpi=300,bbox_inches = 'tight')#_nospine

# %% [markdown]
# ### east

# %%
for noise in [5,10,20,50,100]:
    f = 'distance_light'
    q = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_5km/8/plot/east/pdp_csv/pdp_distance_light.csv')## 这里是先搞一个统一的distance_light
    q.columns = ['distance_light','random_0']
    for i in range(0,50):
        pdp_path = '/home/wb/Documents/nc_noiseanalysi/noise/noise_%skm/%s/plot'%(noise,i)
        region = 'east'
        pdpfile = pdp_path+'/%s'%region+'/pdp_csv/'+"pdp_%s.csv"%f
        pdpfile = pd.read_csv(pdpfile)
        column_name = 'random_'+str(i)
        q[column_name]= pdpfile['partial_dependence']
    q['init_pdp'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['partial_dependence']
    q['init_x'] = pd.read_csv(r'/home/wb/Documents/nc_noiseanalysi/inital_pdp/%s/%s/pdp_csv/pdp_distance_light.csv'%(region,region))['distance_light']
    q['mean_pdp'] = q.iloc[:,1:-2].mean(axis=1)
    q.iloc[20,-2]=400

    fig,ax = plt.subplots(figsize = (8,6))
    sns.set(style='white', font='sans-serif',font_scale=2)
    #sns.set_context("talk",font_scale=1)
    #sns.despine(top=True, right=True, left=False, bottom=False,ax=ax)

    for i in range(0,50):
        sns.lineplot(x='distance_light',y='random_%s'%i,data=q,ax=ax,color="#606060",linewidth=1.2,alpha=0.6)
        #ax.set_ybound(0.45,0.55)
    sns.lineplot(x='init_x',y='init_pdp',data=q,ax=ax,color="#F03A39",linewidth=4,alpha=1)
    sns.lineplot(x='distance_light',y='mean_pdp',data=q,ax=ax,color="#000000",linewidth=4,alpha=1)

    #ax.set_xbound(-20,400)
    #ax.set_ybound(0.45,0.60)
    ax.set_xticks([0,100,200,300,400])
    #ax.set_yticks([0.47,0.50,0.54,0.56])
    ax.set_xlim(-20,420)
    ax.set_ylim(0.45,0.66)
    #bins = 
    ax.yaxis.set_major_locator(MultipleLocator(0.05))

    plt.setp(ax.get_xticklines(),visible=True)
    plt.setp(ax.get_yticklines(),visible=True)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')

    ax.set_ylabel('Distribution probability',labelpad=10)
    ax.set_xlabel('Distance to light (km)',labelpad=10)
    custom_lines = [
                    Line2D([0], [0], color="#F03A39", lw=5,alpha=1),##F02A2A,#F05339,#F03A39
                    Line2D([0], [0], color="#000000", lw=5,alpha=1),##5866AF,5833AF,606060
                    Line2D([0], [0], color='#606060', lw=5,alpha=0.6),
                    ]

    #ax.legend(custom_lines, ['Original','Average noises','Random noises'],loc=(0.45,0.01),frameon=False)#,loc=(0.65,0.85)
    title_value = pdp_path.split('/')[6].split('_')[1][:-2]
    title = '%s km '%title_value
    plt.title(label=title,pad=5,font={'size':28})
    plt.savefig(r'/home/wb/Documents/nc_noiseanalysi/noise/noise_added_pdp//%s/%s.png'%(region,title),dpi=300,bbox_inches = 'tight')#_nospine
